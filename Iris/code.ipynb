# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("iris.csv")
data
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data["class"].drop_duplicates()
# Out:
# 0          Iris-setosa
# 50     Iris-versicolor
# 100     Iris-virginica
# Name: class, dtype: object

# %%
data.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Sentosa

# %%
sentosa = data[data["class"]== "Iris-setosa"]
sentosa.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
plt.scatter(sentosa["sepal length"], sentosa["sepal width"], color = "green", label = "sepal")
plt.scatter(sentosa["petal length"], sentosa["petal width"], color = "purple", label = "petal")
plt.legend()
plt.title("Sentosa")
# Out:
# Text(0.5, 1.0, 'Sentosa')

# %% [markdown]
# # Versicolor

# %%
versicolor = data[data["class"] == "Iris-versicolor"]
versicolor.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
plt.scatter(versicolor["sepal length"], versicolor["sepal width"], color = "green", label= "sepal")
plt.scatter(versicolor["petal length"], versicolor["petal width"], color = "purple", label = "petal")
plt.legend()
plt.title("Versicolor")
# Out:
# Text(0.5, 1.0, 'Versicolor')

# %% [markdown]
# # Virginica

# %%
virginica = data[data["class"] == "Iris-virginica"]
virginica.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
plt.scatter(virginica["sepal length"], virginica["sepal width"], color = "green", label= "sepal")
plt.scatter(virginica["petal length"], virginica["petal width"], color = "purple", label= "petal")
plt.legend()
plt.title("Virginica")
plt.show()

# %% [markdown]
# # Visualizing whole data

# %%
sns.violinplot(x = "sepal length", y = "class", data = data , hue = "class")
plt.show()
# violin plot - https://www.youtube.com/watch?v=Rw00VmP--qk&t=221s

# %%
sns.violinplot(x = "sepal width", y = "class", data = data, hue = "class")
plt.show()

# %%
sns.scatterplot(data = data, x = "sepal width", y = "class", hue = "class")
plt.show()

# %%
sns.violinplot(x = "petal length", y = "class", data = data, hue = "class")
plt.show()

# %%
sns.violinplot(x = "petal width", y = "class", data = data, hue = "class")
plt.show()

# %%
# Pairplot
sns.pairplot(data = data, hue = "class")
plt.show()

# %% [markdown]
# Here you can see how sentosa is always isolated from versicolor and viginica

# %%
plt.figure(figsize=(7,5))
sns.heatmap(data.corr(method = "pearson", numeric_only = True), annot=True, cmap='cubehelix_r')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(data.corr(method = "kendall", numeric_only = True), annot=True, cmap='cubehelix_r')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(data.corr(method = "spearman", numeric_only = True), annot=True, cmap='cubehelix_r')
plt.show()

# %% [markdown]
# # Model Building

# %%
# Train and Test split
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

X = data[["sepal length", "sepal width", "petal length","petal width"]]
y = data[["class"]]

X_train, X_test, y_train, y_test = train_test_split(X, y.values.ravel(), test_size = 0.2, random_state = 42)

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

LR_model = LogisticRegression()
LR_model.fit(X_train, y_train)
hat = LR_model.predict(X_test)
print("Accuracy of Logistic Regression is ", accuracy_score(y_test,hat))

f1 = f1_score(y_test, hat, average = "macro")
print(f1)
# Out:
# Accuracy of Logistic Regression is  1.0
# 1.0

# %%
# Support Vector Machine (SVM)
from sklearn.svm import SVC

svm = SVC()
svm.fit(X_train, y_train)
hat = svm.predict(X_test)
print("Accuracy of SVM is: ", accuracy_score(y_test, hat))
# Out:
# Accuracy of SVM is:  1.0

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(X_train, y_train)
hat = DT.predict(X_test)
print("Accuracy of Decision Tree: ",accuracy_score(y_test,hat))
# Out:
# Accuracy of Decision Tree:  1.0

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier()
RF.fit(X_train,y_train)
hat = RF.predict(X_test)
print("Accuracy of Random Forest: ", accuracy_score(y_test,hat))
# Out:
# Accuracy of Random Forest:  1.0

# %%
# Neural Network
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

nn = MLPClassifier(hidden_layer_sizes= (10,), max_iter = 2000)
nn.fit(X_train, y_train)
hat = nn.predict(X_test)
print("Accuracy of Neural Network: ", accuracy_score(y_test, hat))
# Out:
# Accuracy of Neural Network:  1.0

# %% [markdown]
# # Building UI

# %%
import joblib
joblib.dump(svm, "model.pkl")
# Out:
# ['model.pkl']

# %%
# Min and Max lenght and Width of each attrribute
sub_set = data[["sepal length", "sepal width", "petal length", "petal width"]]
print("Minimum of each attribute:")
print(sub_set.min())
print()
print("Maximum of each attribute:")
print(sub_set.max())
# User have to enter value between these range.
# Out:
# Minimum of each attribute:
# sepal length    4.3
# sepal width     2.0
# petal length    1.0
# petal width     0.1
# dtype: float64
#
# Maximum of each attribute:
# sepal length    7.9
# sepal width     4.4
# petal length    6.9
# petal width     2.5
# dtype: float64

# %%
min_value = sub_set.min()
sns.barplot(x = min_value.index, y = min_value.values, hue = min_value)
plt.ylabel("Minimum value")
plt.xlabel("Attributes")
plt.title("Minimum value of each attribute")
plt.show()

# %%
max_value = sub_set.max()
sns.barplot(x = max_value.index, y = max_value.values, hue = max_value)
plt.ylabel("Maximum value")
plt.xlabel("Attributes")
plt.title("Maximum value of each attribute")
plt.show()

# %%
import joblib

model = joblib.load("model.pkl")

prediction = model.predict([[5.4,3,4.5,1.5]])[0]
print(prediction)

iris_types = {"Iris-setosa": "Setosa", "Iris-versicolor": "Versicolor", "Iris-virginica": "Virginica"}
iris_images = {"Iris-setosa": "setosa.png", "Iris-versicolor": "versicolor.png", "Iris-virginica": "virginica.png"}

res = iris_types[prediction]
img = iris_images[prediction]

print(res)
print(img)
# Out:
# Iris-versicolor
# Versicolor
# versicolor.png
# c:\Users\ACER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
